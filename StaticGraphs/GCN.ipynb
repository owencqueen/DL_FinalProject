# %% [markdown]
# # Static Graph Predictions - Graph Convolutional Networks
# This notebook demonstrates the loading of data from the synethetic dataset into tensors that are then used in Pytorch Geometric. We then perform predictions on the final proportion of Heroin individuals in the models. Each prediction is done on a static graph at a given time step. Please see report for more details.
#
# We recommend loading this into Colab to run because the runtime of the GNNs is quite slow without GPUs.

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !pip install -q torch-scatter -f https://pytorch-geometric.com/whl/torch-1.8.0+cu101.html
# !pip install -q torch-sparse -f https://pytorch-geometric.com/whl/torch-1.8.0+cu101.html
# !pip install -q torch-geometric
# Out:
#      |████████████████████████████████| 2.6MB 8.2MB/s
#      |████████████████████████████████| 1.5MB 8.0MB/s
#      |████████████████████████████████| 215kB 7.7MB/s
#      |████████████████████████████████| 235kB 13.2MB/s
#      |████████████████████████████████| 2.2MB 14.9MB/s
#      |████████████████████████████████| 51kB 7.7MB/s
#   Building wheel for torch-geometric (setup.py) ... done

# %%
import sys, os
import numpy as np
from collections import Counter
import warnings

import torch 
import torch.nn as nn
import torch.optim as optim
from torch.nn import Linear
import torch.nn.functional as F

from torch_geometric.data import Data, GraphSAINTRandomWalkSampler, DataLoader, Dataset
from torch_geometric.datasets import Planetoid, Entities
from torch_geometric.nn import GCNConv, RGCNConv, GATConv, SAGEConv, JumpingKnowledge, GINConv, DeepGraphInfomax, global_mean_pool
from torch_geometric.utils.convert import from_networkx, to_networkx

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# To load in the data from pickles:
import pickle, os
import pandas as pd
import networkx as nx

import matplotlib.pyplot as plt

# %%
class Hyperparameters():
  def __init__(self):
    self.num_node_features = None
    self.num_classes = None
    self.lr = 0.005
    self.w_decay = 5e-4   
    self.dropout = 0.3
    self.epochs = 200                
    self.cuda = True                
    self.device  =  None 
    self.batch_size = 32 

args = Hyperparameters()
args.cuda = torch.cuda.is_available() 
if args.cuda:
    args.device = torch.device('cuda:0') # Change device here 
else:
    args.device = torch.device('cpu')
    
print(args.device)
# Out:
# cuda:0

# %%
nx_objects = pickle.load(open('/content/drive/Shareddrives/DL_525/final_proj/net_1000.pickle', 'rb'))

# %%
# Loading data:
group_to_onehot = {
    'S': (1, 0, 0, 0, 0),
    'P': (0, 1, 0, 0, 0),
    'A': (0, 0, 1, 0, 0),
    'H': (0, 0, 0, 1, 0),
    'R': (0, 0, 0, 0, 1)
}

# Gets final proportions of individuals in the graph with a given group
def get_ending_proportions(obj_list, group = 'H'):
  prop_list = []
  for i in range(len(obj_list)):
    subl = obj_list[i]
    group_last = nx.get_node_attributes(subl[-1], 'group')
    group_count = dict(Counter(group_last.values()))
    prop_list.append(group_count[group_to_onehot[group]] / subl[-1].number_of_nodes())
  return prop_list
    
end_prop = get_ending_proportions(nx_objects)
Y = end_prop # Set Y value (can be anything)

# %%
# Functions to get initial graphs:

def conv_to_undirected(edges):
  undirected_edges = list(edges)
  for e in edges:
    undirected_edges.append([e[1], e[0]])
  return undirected_edges


def get_X_static(tstep = 0):
  '''
  Gets the X for one network in a series
  Arguments:
  ----------
  tstep: integer
  '''

  X = []

  for i in range(0, len(nx_objects)):
    edge_list = conv_to_undirected(nx_objects[i][tstep].edges)
    edge_index = torch.tensor(edge_list, dtype=torch.long).to(args.device)
    node_attr = dict(nx.get_node_attributes(nx_objects[i][tstep], 'group'))
    # Order the node attributes:
    x = torch.tensor(
        [node_attr[i] 
        for i in range(len(nx_objects[i][tstep].nodes))], dtype = torch.float
    ).to(args.device)
    d = Data(x=x, edge_index=edge_index.t().contiguous())
    X.append([d, Y[i]])

  return X

def train_val_split(dataset, X, val_split = 0.25):
  '''Split data into train-validation split'''

  train_ind, val_ind = train_test_split(list(range(len(dataset))), test_size = val_split)
  train = [X[t] for t in train_ind]
  val = [X[v] for v in val_ind]

  # Puts all training and val data in a DataLoader wrapper
  train_dataset = DataLoader(train, batch_size = 64, shuffle = True)
  val_dataset = DataLoader(val, batch_size = 64, shuffle = False)
  return train_dataset, val_dataset

# %%
time_step = 95 # Which time step to evaluate

X_full = get_X_static(tstep = time_step)
print('Number of samples', len(X_full))

dataset = X_full
train_dataset, val_dataset = train_val_split(dataset, X_full, val_split = 0.25)
# Out:
# Number of samples 1000

# %% [markdown]
# ## Define the Models
# Define each of the GNN architectures to use. Each architecture varies the number of convolutional layers.
#
# **Terminology:**
# - Hidden channels: number of dimensions for embedding vectors within the message-passing layers.

# %%
class GCN3(torch.nn.Module):
    def __init__(self, hidden_channels):
        super(GCN3, self).__init__()
        self.conv1 = GCNConv(5, hidden_channels)
        self.lin = Linear(hidden_channels, 1) # One value in output
        self.sig = nn.Sigmoid()

    def forward(self, x, edge_index, batch):
        # 1. Obtain node embeddings 
        x = self.conv1(x, edge_index)
        x = x.relu()

        # 2. Readout layer
        x = global_mean_pool(x, batch)  # [batch_size, hidden_channels]

        # 3. Apply a final classifier
        x = F.dropout(x, p=0.25, training=self.training)

        # Since we have a proportion to predict, squashing to [0,1]
        x = self.lin(x)
        
        return x

gnn_description = 'GCN Conv 1 layers, 64 hidden channels each, drop=0.25'
gcn_no = 3

# %%
class GCN2(torch.nn.Module):
    def __init__(self, hidden_channels):
        super(GCN2, self).__init__()
        self.conv1 = GCNConv(5, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, hidden_channels)
        self.lin = Linear(hidden_channels, 1) # One value in output
        self.sig = nn.Sigmoid()

    def forward(self, x, edge_index, batch):
        # 1. Obtain node embeddings 
        x = self.conv1(x, edge_index)
        x = x.relu()
        x = self.conv2(x, edge_index)
        x = x.relu()

        # 2. Readout layer
        x = global_mean_pool(x, batch)  # [batch_size, hidden_channels]

        # 3. Apply a final classifier
        x = F.dropout(x, p=0.25, training=self.training)

        # Since we have a proportion to predict, squashing to [0,1]
        x = self.lin(x)
        
        return x

gnn_description = 'GCN Conv 2 layers, 64 hidden channels each, drop=0.25'
gcn_no = 2

# %%
class GCN(torch.nn.Module):
    def __init__(self, hidden_channels):
        super(GCN, self).__init__()
        self.conv1 = GCNConv(5, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, hidden_channels)
        self.conv3 = GCNConv(hidden_channels, hidden_channels)
        self.lin = Linear(hidden_channels, 1) # One value in output
        self.sig = nn.Sigmoid()

    def forward(self, x, edge_index, batch):
        # 1. Obtain node embeddings 
        x = self.conv1(x, edge_index)
        x = x.relu()
        x = self.conv2(x, edge_index)
        x = x.relu()
        x = self.conv3(x, edge_index)

        # 2. Readout layer
        x = global_mean_pool(x, batch)  # [batch_size, hidden_channels]

        # 3. Apply a final classifier
        x = F.dropout(x, p=0.25, training=self.training)

        # Since we have a proportion to predict, squashing to [0,1]
        x = self.lin(x)
        
        return x
    
gnn_description = 'GCN Conv 3 layers, 64 hidden channels each, drop=0.25'
gcn_no = 1

# %% [markdown]
# ## Training the Models
# In the below block, we train a defined model with the given hyperparameters, plotting an accuracy curve upon completion.

# %%
with warnings.catch_warnings():
  warnings.simplefilter("ignore")
  hc = 256 # Number of hidden channels
  model = GCN3(hidden_channels=hc).to(device=args.device)
  learn_r = 0.01 # Learning rate
  optimizer = torch.optim.Adam(model.parameters(), lr=learn_r)
  criterion = torch.nn.MSELoss()

  epochs = 100

  def train():
    '''Trains the model'''
    model.train()

    for Xdata, Ydata in train_dataset:  # Iterate in batches over the training dataset.
      #print('Epoch', i)
      #print(data)
      out = model(Xdata.x.to(args.device), Xdata.edge_index.to(args.device), Xdata.batch.to(args.device))  # Perform a single forward pass.
      loss = criterion(out, Ydata.to(args.device))  # Compute the loss.
      loss.backward()  # Derive gradients.
      optimizer.step()  # Update parameters based on gradients.
      optimizer.zero_grad()  # Clear gradients.

  def test(loader):
    model.eval()

    preds = []
    gt = []
    for Xdata, Ydata in loader:  # Iterate in batches over the training/test dataset.
      pred = model(Xdata.x.to(args.device), Xdata.edge_index.to(args.device), Xdata.batch.to(args.device)) 
      preds.append(pred.cpu().detach().numpy())
      gt.append(Ydata.detach().numpy())

    return r2_score(np.concatenate(gt), np.concatenate(preds))

  train_curve = []
  test_curve = []
  for epoch in range(0, epochs):
    train()
    train_acc = test(train_dataset)
    train_curve.append(train_acc)
    test_acc = test(val_dataset)
    test_curve.append(test_acc)
    print(f'Epoch: {epoch:03d}, Train R^2: {train_acc:.4f}, Test R^2: {test_acc:.4f}')

#gnn_description = 'GCN Conv 3 layers, 64 hidden channels each, drop=0.25'
results = pd.DataFrame({'train_results':train_curve, 'test_curve':test_curve})
results['model'] = [gnn_description] + [None] * (len(train_curve) - 1)
#results.to_csv(f'gnn_lr={learn_r}_curves_t={time_step}.csv', index = False)
#results.to_csv(f'gnn_hc={hc}_curves_t={time_step}.csv', index = False)

plt.figure(figsize=(10, 8), dpi = 100)
plt.plot(list(range(epochs)), train_curve, label = 'Training R^2')
plt.plot(list(range(epochs)), test_curve, label = 'Testing R^2')
plt.legend()
plt.title('GCN {} - $R^2$ Predicting Final H - Time Step = {}'.format(gcn_no, time_step))
plt.xlabel('Epochs')
plt.ylabel('$R^2$')
plt.show()
# Out:
# Epoch: 000, Train R^2: -4.5805, Test R^2: -4.7308
# Epoch: 001, Train R^2: -0.3116, Test R^2: -0.2889
# Epoch: 002, Train R^2: -0.1568, Test R^2: -0.2235
# Epoch: 003, Train R^2: 0.0231, Test R^2: -0.0024
# Epoch: 004, Train R^2: 0.0082, Test R^2: 0.0132
# Epoch: 005, Train R^2: 0.0377, Test R^2: 0.0325
# Epoch: 006, Train R^2: 0.0404, Test R^2: 0.0257
# Epoch: 007, Train R^2: 0.0441, Test R^2: 0.0362
# Epoch: 008, Train R^2: 0.0417, Test R^2: 0.0358
# Epoch: 009, Train R^2: 0.0445, Test R^2: 0.0339
# Epoch: 010, Train R^2: 0.0433, Test R^2: 0.0352
# Epoch: 011, Train R^2: 0.0411, Test R^2: 0.0363
# Epoch: 012, Train R^2: 0.0405, Test R^2: 0.0291
# Epoch: 013, Train R^2: 0.0351, Test R^2: 0.0303
# Epoch: 014, Train R^2: 0.0341, Test R^2: 0.0217
# Epoch: 015, Train R^2: 0.0318, Test R^2: 0.0286
# Epoch: 016, Train R^2: 0.0301, Test R^2: 0.0183
# Epoch: 017, Train R^2: 0.0277, Test R^2: 0.0203
# Epoch: 018, Train R^2: 0.0261, Test R^2: 0.0213
# Epoch: 019, Train R^2: 0.0260, Test R^2: 0.0180
# Epoch: 020, Train R^2: 0.0229, Test R^2: 0.0093
# Epoch: 021, Train R^2: 0.0225, Test R^2: 0.0197
# Epoch: 022, Train R^2: 0.0245, Test R^2: 0.0121
# Epoch: 023, Train R^2: 0.0297, Test R^2: 0.0278
# Epoch: 024, Train R^2: 0.0365, Test R^2: 0.0263
# Epoch: 025, Train R^2: 0.0313, Test R^2: 0.0280
# Epoch: 026, Train R^2: 0.0314, Test R^2: 0.0212
# Epoch: 027, Train R^2: 0.0351, Test R^2: 0.0280
# Epoch: 028, Train R^2: 0.0363, Test R^2: 0.0339
# Epoch: 029, Train R^2: 0.0369, Test R^2: 0.0251
# Epoch: 030, Train R^2: 0.0336, Test R^2: 0.0325
# Epoch: 031, Train R^2: 0.0377, Test R^2: 0.0278
# Epoch: 032, Train R^2: 0.0367, Test R^2: 0.0337
# Epoch: 033, Train R^2: 0.0415, Test R^2: 0.0374
# Epoch: 034, Train R^2: 0.0431, Test R^2: 0.0398
# Epoch: 035, Train R^2: 0.0436, Test R^2: 0.0379
# Epoch: 036, Train R^2: 0.0427, Test R^2: 0.0395
# Epoch: 037, Train R^2: 0.0495, Test R^2: 0.0446
# Epoch: 038, Train R^2: 0.0425, Test R^2: 0.0401
# Epoch: 039, Train R^2: 0.0387, Test R^2: 0.0314
# Epoch: 040, Train R^2: 0.0314, Test R^2: 0.0318
# Epoch: 041, Train R^2: 0.0417, Test R^2: 0.0306
# Epoch: 042, Train R^2: 0.0421, Test R^2: 0.0433
# Epoch: 043, Train R^2: 0.0450, Test R^2: 0.0389
# Epoch: 044, Train R^2: 0.0354, Test R^2: 0.0300
# Epoch: 045, Train R^2: 0.0288, Test R^2: 0.0253
# Epoch: 046, Train R^2: 0.0387, Test R^2: 0.0367
# Epoch: 047, Train R^2: 0.0433, Test R^2: 0.0354
# Epoch: 048, Train R^2: 0.0458, Test R^2: 0.0444
# Epoch: 049, Train R^2: 0.0424, Test R^2: 0.0405
# Epoch: 050, Train R^2: 0.0387, Test R^2: 0.0362
# Epoch: 051, Train R^2: 0.0350, Test R^2: 0.0347
# Epoch: 052, Train R^2: 0.0372, Test R^2: 0.0320
# Epoch: 053, Train R^2: 0.0387, Test R^2: 0.0304
# Epoch: 054, Train R^2: 0.0340, Test R^2: 0.0353
# Epoch: 055, Train R^2: 0.0389, Test R^2: 0.0318
# Epoch: 056, Train R^2: 0.0380, Test R^2: 0.0377
# Epoch: 057, Train R^2: 0.0327, Test R^2: 0.0299
# Epoch: 058, Train R^2: 0.0288, Test R^2: 0.0218
# Epoch: 059, Train R^2: 0.0307, Test R^2: 0.0270
# Epoch: 060, Train R^2: 0.0295, Test R^2: 0.0299
# Epoch: 061, Train R^2: 0.0321, Test R^2: 0.0291
# Epoch: 062, Train R^2: 0.0340, Test R^2: 0.0319
# Epoch: 063, Train R^2: 0.0297, Test R^2: 0.0291
# Epoch: 064, Train R^2: 0.0306, Test R^2: 0.0241
# Epoch: 065, Train R^2: 0.0307, Test R^2: 0.0287
# Epoch: 066, Train R^2: 0.0233, Test R^2: 0.0212
# Epoch: 067, Train R^2: 0.0197, Test R^2: 0.0172
# Epoch: 068, Train R^2: 0.0176, Test R^2: 0.0167
# Epoch: 069, Train R^2: 0.0228, Test R^2: 0.0174
# Epoch: 070, Train R^2: 0.0257, Test R^2: 0.0277
# Epoch: 071, Train R^2: 0.0312, Test R^2: 0.0275
# Epoch: 072, Train R^2: 0.0251, Test R^2: 0.0282
# Epoch: 073, Train R^2: 0.0248, Test R^2: 0.0211
# Epoch: 074, Train R^2: 0.0210, Test R^2: 0.0195
# Epoch: 075, Train R^2: 0.0199, Test R^2: 0.0078
# Epoch: 076, Train R^2: 0.0179, Test R^2: 0.0233
# Epoch: 077, Train R^2: 0.0315, Test R^2: 0.0255
# Epoch: 078, Train R^2: 0.0341, Test R^2: 0.0353
# Epoch: 079, Train R^2: 0.0385, Test R^2: 0.0347
# Epoch: 080, Train R^2: 0.0382, Test R^2: 0.0322
# Epoch: 081, Train R^2: 0.0317, Test R^2: 0.0332
# Epoch: 082, Train R^2: 0.0265, Test R^2: 0.0153
# Epoch: 083, Train R^2: 0.0334, Test R^2: 0.0335
# Epoch: 084, Train R^2: 0.0349, Test R^2: 0.0288
# Epoch: 085, Train R^2: 0.0351, Test R^2: 0.0361
# Epoch: 086, Train R^2: 0.0334, Test R^2: 0.0304
# Epoch: 087, Train R^2: 0.0318, Test R^2: 0.0340
# Epoch: 088, Train R^2: 0.0335, Test R^2: 0.0267
# Epoch: 089, Train R^2: 0.0258, Test R^2: 0.0267
# Epoch: 090, Train R^2: 0.0236, Test R^2: 0.0152
# Epoch: 091, Train R^2: 0.0372, Test R^2: 0.0352
# Epoch: 092, Train R^2: 0.0379, Test R^2: 0.0411
# Epoch: 093, Train R^2: 0.0473, Test R^2: 0.0470
# Epoch: 094, Train R^2: 0.0439, Test R^2: 0.0412
# Epoch: 095, Train R^2: 0.0328, Test R^2: 0.0373
# Epoch: 096, Train R^2: 0.0355, Test R^2: 0.0282
# Epoch: 097, Train R^2: 0.0340, Test R^2: 0.0274
# Epoch: 098, Train R^2: 0.0220, Test R^2: 0.0265
# Epoch: 099, Train R^2: 0.0173, Test R^2: 0.0033

# %% [markdown]
# ## Plotting Tools
# The code below was used to plot the accuracy curves. Please do not run this code, it is simply here for demonstration purposes.

# %%
import matplotlib.pyplot as plt

gcn3 = pd.read_csv('gnn_3_layer_curves_t=95.csv')
gcn2 = pd.read_csv('gnn_2_layer_curves_t=95.csv')
gcn1 = pd.read_csv('gnn_1_layer_curves_t=95.csv')

labels = ['GCN 1 Layer', 'GCN 2 Layers', 'GCN 3 Layers']

x = list(range(0, gcn1.shape[0]))

plt.figure(figsize=(8, 6), dpi = 150)
plt.plot(x, gcn3['test_curve'], label = labels[0])
plt.plot(x, gcn2['test_curve'], label = labels[1])
plt.plot(x, gcn1['test_curve'], label = labels[2])

plt.title('Comparing GCNs - Number of Layers')
plt.xlabel('Epochs')
plt.ylabel('Coef. of Determination')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

lrs = [0.001, 0.01, 0.1]

gcn3 = pd.read_csv(f'gnn_lr={lrs[0]}_curves_t=95.csv')
gcn3['test_curve'].iloc[0] = -2.0
gcn2 = pd.read_csv(f'gnn_lr={lrs[1]}_curves_t=95.csv')
gcn1 = pd.read_csv(f'gnn_lr={lrs[2]}_curves_t=95.csv')

labels = [f'GCN Learning Rate = {lrs[i]}' for i in range(len(lrs))]

x = list(range(0, gcn1.shape[0]))

plt.figure(figsize=(8, 6), dpi = 150)
plt.plot(x, gcn3['test_curve'], label = labels[0])
plt.plot(x, gcn2['test_curve'], label = labels[1])
plt.plot(x, gcn1['test_curve'], label = labels[2])

plt.title('Comparing GCNs - Learning Rate')
plt.xlabel('Epochs')
plt.ylabel('Coef. of Determination')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
import matplotlib.pyplot as plt

hcs = [32, 64, 128, 256]

gcn4 = pd.read_csv(f'gnn_hc={hcs[0]}_curves_t=95.csv')
gcn3 = pd.read_csv(f'gnn_hc={hcs[1]}_curves_t=95.csv')
gcn2 = pd.read_csv(f'gnn_hc={hcs[2]}_curves_t=95.csv')
gcn1 = pd.read_csv(f'gnn_hc={hcs[3]}_curves_t=95.csv')

gcns = [gcn4, gcn3, gcn2, gcn1]

labels = [f'GCN No. Hidden Channels = {hcs[i]}' for i in range(len(hcs))]

x = list(range(0, gcn1.shape[0]))

bottom = 4

plt.figure(figsize=(8, 6), dpi = 150)

for i in range(len(hcs)):
  plt.plot(x[bottom:], gcns[i]['test_curve'].iloc[bottom:], label = labels[i])
  
# plt.plot(x, gcn2['test_curve'], label = labels[1])
# plt.plot(x, gcn1['test_curve'], label = labels[2])

plt.title('Comparing GCNs - Number of Hidden Channels')
plt.xlabel('Epochs')
plt.ylabel('Coef. of Determination')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

t = [0, 25, 50, 75, 90, 95, 99]

gcns = []

for i in range(len(t)):
  gcn_temp = pd.read_csv('gcn1_curves/gcn1_curves_t={}.csv'.format(t[i]))
  gcns.append(gcn_temp)

labels = [f'GCN Starting Time Step = {t[i]}' for i in range(len(t))]

x = list(range(0, gcns[0].shape[0]))

bottom = 2

plt.figure(figsize=(8, 6), dpi = 150)

for i in range(len(t)):
  plt.plot(x[bottom:], gcns[i]['test_curve'].iloc[bottom:], label = labels[i])
  
# plt.plot(x, gcn2['test_curve'], label = labels[1])
# plt.plot(x, gcn1['test_curve'], label = labels[2])

plt.title('Comparing GCNs - Time Steps')
plt.xlabel('Epochs')
plt.ylabel('Coef. of Determination')
plt.legend()
plt.show()
